# %% [markdown]
# ## Importamos las librerias necesarias

# %%
import pandas as pd

# %% [markdown]
# ## Leemos el fichero csv de Git

# %%
url="https://raw.githubusercontent.com/Violainedlst/proyecto-da-promo-H-modulo-3-team-2-People-pulse/main/HR%20RAW%20DATA.csv"
data = pd.read_csv(url)

# %% [markdown]
# ## Sacamos la información de csv para ver los tipos de datos de cada columna

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1614 entries, 0 to 1613
# Data columns (total 42 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                1614 non-null   int64
#  1   Age                       1614 non-null   object
#  2   Attrition                 1614 non-null   object
#  3   BusinessTravel            842 non-null    object
#  4   DailyRate                 1614 non-null   object
#  5   Department                302 non-null    object
#  6   DistanceFromHome          1614 non-null   int64
#  7   Education                 1614 non-null   int64
#  8   EducationField            869 non-null    object
#  9   employeecount             1614 non-null   int64
#  10  employeenumber            1183 non-null   object
#  11  EnvironmentSatisfaction   1614 non-null   int64
#  12  Gender                    1614 non-null   int64
#  13  HourlyRate                1614 non-null   object
#  14  JobInvolvement            1614 non-null   int64
#  15  JobLevel                  1614 non-null   int64
#  16  JobRole                   1614 non-null   object
#  17  JobSatisfaction           1614 non-null   int64
#  18  MaritalStatus             963 non-null    object
#  19  MonthlyIncome             771 non-null    object
#  20  MonthlyRate               1614 non-null   int64
#  21  NUMCOMPANIESWORKED        1614 non-null   int64
#  22  Over18                    713 non-null    object
#  23  OverTime                  938 non-null    object
#  24  PercentSalaryHike         1614 non-null   int64
#  25  PerformanceRating         1419 non-null   object
#  26  RelationshipSatisfaction  1614 non-null   int64
#  27  StandardHours             419 non-null    object
#  28  StockOptionLevel          1614 non-null   int64
#  29  TOTALWORKINGYEARS         1088 non-null   object
#  30  TrainingTimesLastYear     1614 non-null   int64
#  31  WORKLIFEBALANCE           1506 non-null   object
#  32  YearsAtCompany            1614 non-null   int64
#  33  YearsInCurrentRole        34 non-null     object
#  34  YearsSinceLastPromotion   1614 non-null   int64
#  35  YEARSWITHCURRMANAGER      1614 non-null   int64
#  36  SameAsMonthlyIncome       771 non-null    object
#  37  DateBirth                 1614 non-null   int64
#  38  Salary                    1614 non-null   object
#  39  RoleDepartament           302 non-null    object
#  40  NUMBERCHILDREN            0 non-null      float64
#  41  RemoteWork                1614 non-null   object
# dtypes: float64(1), int64(19), object(22)
# memory usage: 529.7+ KB

# %% [markdown]
# ## Recorremos las columnas para ver la información que contiene cada una

# %%
for column in data.columns:
  
    print(f"Columna: {column}")
    print(data[column].unique())

    print("\n--------------------\n")
# Out:
# Columna: Unnamed: 0
# [   0    1    2 ... 1611 1612 1613]
#
# --------------------
#
# Columna: Age
# ['51' '52' '42' '47' '46' '48' '59' '41' '56' '38' '55' '40' '58' '35'
#  '45' '33' '36' '34' 'forty-seven' '53' '43' '60' '32' '37' '49' '39' '50'
#  '44' '30' 'fifty-eight' '29' '31' '54' '57' '27' 'thirty-six' '28' '26'
#  'fifty-five' '25' 'fifty-two' 'thirty-one' '24' 'thirty' '23' '22' '21'
#  '20' 'twenty-six' '19' 'thirty-seven' '18' 'thirty-two' 'twenty-four']
#
# --------------------
#
# Columna: Attrition
# ['No' 'Yes']
#
# --------------------
#
# Columna: BusinessTravel
# [nan 'travel_rarely' 'travel_frequently' 'non-travel']
#
# --------------------
#
# Columna: DailyRate
# ['684,0$' '699,0$' '532,0$' '359,0$' '1319,0$' '117,0$' '1435,0$' '635,0$'
#  '1276,0$' '840,0$' '247,0$' '1369,0$' '201,0$' '1360,0$' '692,0$'
#  '1398,0$' '286,0$' '1402,0$' '819,0$' '884,0$' '1238,0$' '515,0$'
#  '1223,0$' '202,0$' '928,0$' '607,0$' '266,0$' '429,0$' '589,0$' 'nan$'
#  '1180,0$' '1282,0$' '776,0$' '665,0$' '526,0$' '1034,0$' '1403,0$'
#  '1499,0$' '580,0$' '859,0$' '263,0$' '1376,0$' '885,0$' '1003,0$'
#  '1321,0$' '394,0$' '1372,0$' '1333,0$' '228,0$' '737,0$' '823,0$'
#  '667,0$' '301,0$' '573,0$' '1329,0$' '630,0$' '1063,0$' '1017,0$'
#  '1296,0$' '939,0$' '1355,0$' '1448,0$' '200,0$' '1202,0$' '404,0$'
#  '208,0$' '813,0$' '465,0$' '1189,0$' '1001,0$' '1394,0$' '161,0$'
#  '288,0$' '682,0$' '1354,0$' '147,0$' '119,0$' '1413,0$' '452,0$' '334,0$'
#  '1132,0$' '982,0$' '480,0$' '1099,0$' '672,0$' '1379,0$' '583,0$'
#  '1492,0$' '1050,0$' '469,0$' '237,0$' '1440,0$' '1291,0$' '1157,0$'
#  '1336,0$' '1224,0$' '735,0$' '1389,0$' '638,0$' '1240,0$' '194,0$'
#  '1339,0$' '111,0$' '1469,0$' '470,0$' '1232,0$' '1249,0$' '798,0$'
#  '549,0$' '570,0$' '541,0$' '164,0$' '1117,0$' '619,0$' '319,0$' '956,0$'
#  '1245,0$' '1397,0$' '527,0$' '213,0$' '882,0$' '330,0$' '406,0$' '217,0$'
#  '481,0$' '669,0$' '1465,0$' '685,0$' '1062,0$' '177,0$' '1199,0$'
#  '648,0$' '412,0$' '282,0$' '770,0$' '601,0$' '855,0$' '332,0$' '1326,0$'
#  '748,0$' '405,0$' '790,0$' '971,0$' '1370,0$' '750,0$' '880,0$' '678,0$'
#  '1179,0$' '350,0$' '1266,0$' '574,0$' '189,0$' '310,0$' '722,0$'
#  '1219,0$' '994,0$' '721,0$' '853,0$' '427,0$' '852,0$' '1334,0$'
#  '1093,0$' '967,0$' '989,0$' '1195,0$' '1045,0$' '829,0$' '663,0$'
#  '1300,0$' '1105,0$' '906,0$' '849,0$' '1275,0$' '1218,0$' '422,0$'
#  '1274,0$' '1076,0$' '1207,0$' '430,0$' '933,0$' '1184,0$' '586,0$'
#  '890,0$' '379,0$' '1425,0$' '1188,0$' '938,0$' '1053,0$' '248,0$'
#  '796,0$' '174,0$' '408,0$' '977,0$' '536,0$' '135,0$' '1476,0$' '587,0$'
#  '495,0$' '523,0$' '507,0$' '1055,0$' '1445,0$' '218,0$' '447,0$'
#  '1029,0$' '674,0$' '538,0$' '740,0$' '1234,0$' '170,0$' '1130,0$'
#  '584,0$' '918,0$' '792,0$' '611,0$' '1383,0$' '867,0$' '706,0$' '728,0$'
#  '311,0$' '556,0$' '937,0$' '1125,0$' '444,0$' '911,0$' '585,0$' '1392,0$'
#  '1005,0$' '1299,0$' '655,0$' '746,0$' '632,0$' '658,0$' '1467,0$'
#  '1312,0$' '249,0$' '802,0$' '689,0$' '1395,0$' '1436,0$' '1496,0$'
#  '1480,0$' '313,0$' '894,0$' '290,0$' '1084,0$' '1002,0$' '1242,0$'
#  '1052,0$' '944,0$' '771,0$' '1416,0$' '1327,0$' '488,0$' '1385,0$'
#  '666,0$' '1315,0$' '442,0$' '950,0$' '691,0$' '1018,0$' '559,0$' '318,0$'
#  '144,0$' '1171,0$' '143,0$' '1178,0$' '1107,0$' '645,0$' '1485,0$'
#  '1116,0$' '163,0$' '561,0$' '426,0$' '509,0$' '258,0$' '525,0$' '238,0$'
#  '482,0$' '397,0$' '243,0$' '806,0$' '1442,0$' '929,0$' '827,0$' '703,0$'
#  '294,0$' '314,0$' '654,0$' '501,0$' '954,0$' '1434,0$' '657,0$' '240,0$'
#  '791,0$' '676,0$' '436,0$' '760,0$' '661,0$' '1085,0$' '154,0$' '1283,0$'
#  '616,0$' '498,0$' '530,0$' '805,0$' '903,0$' '1229,0$' '566,0$' '1441,0$'
#  '153,0$' '1066,0$' '145,0$' '1109,0$' '124,0$' '300,0$' '1366,0$'
#  '857,0$' '1204,0$' '1082,0$' '203,0$' '1308,0$' '718,0$' '593,0$'
#  '1384,0$' '1361,0$' '1146,0$' '1316,0$' '363,0$' '1103,0$' '920,0$'
#  '694,0$' '1429,0$' '531,0$' '621,0$' '604,0$' '325,0$' '1030,0$' '524,0$'
#  '943,0$' '1009,0$' '817,0$' '930,0$' '1147,0$' '652,0$' '337,0$'
#  '1136,0$' '326,0$' '377,0$' '1038,0$' '1490,0$' '1246,0$' '224,0$'
#  '441,0$' '898,0$' '1313,0$' '1015,0$' '1387,0$' '1302,0$' '602,0$'
#  '772,0$' '809,0$' '786,0$' '921,0$' '717,0$' '979,0$' '953,0$' '244,0$'
#  '196,0$' '303,0$' '1092,0$' '261,0$' '1422,0$' '1137,0$' '511,0$'
#  '1396,0$' '1096,0$' '1169,0$' '1239,0$' '157,0$' '754,0$' '1303,0$'
#  '697,0$' '116,0$' '557,0$' '582,0$' '704,0$' '613,0$' '419,0$' '477,0$'
#  '1211,0$' '505,0$' '269,0$' '553,0$' '1277,0$' '302,0$' '975,0$'
#  '1318,0$' '881,0$' '466,0$' '945,0$' '433,0$' '991,0$' '1083,0$' '136,0$'
#  '333,0$' '1462,0$' '1131,0$' '1023,0$' '1065,0$' '1115,0$' '1479,0$'
#  '304,0$' '1368,0$' '828,0$' '799,0$' '142,0$' '446,0$' '254,0$' '1410,0$'
#  '883,0$' '121,0$' '1343,0$' '490,0$' '1400,0$' '1332,0$' '1200,0$'
#  '1102,0$' '1328,0$' '548,0$' '1214,0$' '120,0$' '841,0$' '1033,0$'
#  '1452,0$' '1268,0$' '307,0$' '797,0$' '555,0$' '1377,0$' '210,0$'
#  '483,0$' '575,0$' '1311,0$' '759,0$' '891,0$' '317,0$' '688,0$' '195,0$'
#  '622,0$' '646,0$' '719,0$' '1012,0$' '1278,0$' '1222,0$' '1231,0$'
#  '462,0$' '231,0$' '1089,0$' '1262,0$' '439,0$' '528,0$' '647,0$'
#  '1097,0$' '942,0$' '966,0$' '168,0$' '299,0$' '999,0$' '1498,0$'
#  '1439,0$' '1111,0$' '1174,0$' '172,0$' '401,0$' '866,0$' '571,0$'
#  '1342,0$' '995,0$' '118,0$' '990,0$' '241,0$' '1470,0$' '492,0$'
#  '1040,0$' '1320,0$' '146,0$' '1153,0$' '185,0$' '1297,0$' '1064,0$'
#  '1351,0$' '468,0$' '1273,0$' '1141,0$' '1488,0$' '653,0$' '1225,0$'
#  '1217,0$' '1127,0$' '1427,0$' '702,0$' '926,0$' '878,0$' '896,0$'
#  '1401,0$' '675,0$' '1070,0$' '496,0$' '390,0$' '1220,0$' '1124,0$'
#  '1046,0$' '267,0$' '443,0$' '1287,0$' '1420,0$' '562,0$' '650,0$'
#  '141,0$' '715,0$' '376,0$' '932,0$' '471,0$' '180,0$' '1265,0$' '1075,0$'
#  '1086,0$' '152,0$' '974,0$' '788,0$' '192,0$' '150,0$' '1167,0$' '206,0$'
#  '736,0$' '322,0$' '683,0$' '1475,0$' '560,0$' '115,0$' '888,0$' '671,0$'
#  '567,0$' '148,0$' '581,0$' '371,0$' '1181,0$' '1253,0$' '370,0$'
#  '1194,0$' '572,0$' '355,0$' '783,0$' '155,0$' '508,0$' '642,0$' '1382,0$'
#  '1037,0$' '1120,0$' '374,0$' '287,0$' '591,0$' '670,0$' '1346,0$'
#  '103,0$' '673,0$' '705,0$' '1459,0$' '1443,0$' '1142,0$' '664,0$'
#  '432,0$' '1353,0$' '489,0$' '807,0$' '1280,0$' '957,0$' '542,0$' '216,0$'
#  '1150,0$' '364,0$' '1256,0$' '440,0$' '713,0$' '140,0$' '629,0$' '328,0$'
#  '472,0$' '905,0$' '1151,0$' '644,0$' '992,0$' '1323,0$' '818,0$'
#  '1431,0$' '976,0$' '832,0$' '916,0$' '1247,0$' '128,0$' '1158,0$'
#  '996,0$' '1449,0$' '636,0$' '889,0$' '106,0$' '723,0$' '1482,0$' '738,0$'
#  '1192,0$' '1309,0$' '544,0$' '641,0$' '756,0$' '895,0$' '1261,0$'
#  '329,0$' '1362,0$' '1371,0$' '821,0$' '1381,0$' '1473,0$' '296,0$'
#  '1349,0$' '986,0$' '413,0$' '988,0$' '1474,0$' '232,0$' '1236,0$'
#  '1112,0$' '204,0$' '913,0$' '810,0$' '693,0$' '316,0$' '381,0$' '775,0$'
#  '804,0$' '1090,0$' '346,0$' '725,0$' '182,0$' '384,0$' '1325,0$'
#  '1258,0$' '1041,0$' '625,0$' '1418,0$' '1269,0$' '395,0$' '341,0$'
#  '500,0$' '1454,0$' '617,0$' '1122,0$' '1198,0$' '188,0$' '335,0$'
#  '461,0$' '1134,0$' '138,0$' '1206,0$' '109,0$' '277,0$' '265,0$' '342,0$'
#  '1186,0$' '769,0$' '1176,0$' '1091,0$' '618,0$' '970,0$' '984,0$'
#  '793,0$' '1182,0$' '603,0$' '874,0$' '367,0$' '199,0$' '1457,0$'
#  '1421,0$' '1450,0$' '1212,0$' '1010,0$' '131,0$' '193,0$' '640,0$'
#  '848,0$' '1138,0$' '256,0$' '935,0$' '458,0$' '662,0$' '499,0$' '949,0$'
#  '383,0$' '1255,0$' '1221,0$' '981,0$' '1495,0$' '1193,0$' '467,0$'
#  '271,0$' '410,0$' '1288,0$' '1108,0$' '437,0$' '457,0$' '634,0$' '546,0$'
#  '711,0$' '448,0$' '365,0$' '763,0$' '486,0$' '392,0$' '727,0$' '741,0$'
#  '552,0$' '506,0$' '1456,0$' '160,0$' '897,0$' '600,0$' '1054,0$' '428,0$'
#  '343,0$' '1216,0$' '207,0$' '280,0$' '414,0$' '836,0$' '592,0$' '219,0$'
#  '1079,0$' '1251,0$' '1168,0$' '1444,0$' '1154,0$' '234,0$' '529,0$'
#  '1322,0$' '924,0$' '134,0$' '755,0$' '253,0$' '922,0$' '1365,0$' '306,0$'
#  '1271,0$' '1404,0$' '1391,0$' '1464,0$' '1330,0$' '773,0$' '902,0$'
#  '107,0$' '504,0$' '1358,0$' '824,0$' '594,0$' '734,0$' '766,0$' '431,0$'
#  '1213,0$' '1373,0$' '1324,0$' '1123,0$' '391,0$' '125,0$' '1357,0$'
#  '626,0$' '132,0$' '871,0$' '1031,0$' '1145,0$' '854,0$' '1411,0$'
#  '252,0$' '833,0$' '1210,0$' '1463,0$' '812,0$' '1162,0$' '845,0$'
#  '1144,0$' '156,0$' '464,0$' '1305,0$' '983,0$' '534,0$' '1306,0$'
#  '1094,0$' '558,0$' '959,0$' '782,0$' '362,0$' '268,0$' '167,0$' '1243,0$'
#  '720,0$' '868,0$' '1252,0$' '781,0$' '1272,0$' '129,0$' '1069,0$'
#  '289,0$' '955,0$' '660,0$' '415,0$' '309,0$' '130,0$' '862,0$' '1098,0$'
#  '969,0$' '373,0$' '599,0$' '968,0$' '830,0$' '1423,0$' '516,0$' '598,0$'
#  '104,0$' '479,0$' '474,0$' '264,0$' '1059,0$' '563,0$' '1259,0$' '369,0$'
#  '543,0$' '964,0$' '176,0$' '181,0$' '211,0$' '590,0$' '305,0$' '478,0$'
#  '1294,0$' '1128,0$' '726,0$' '352,0$' '1172,0$' '605,0$' '1337,0$'
#  '105,0$']
#
# --------------------
#
# Columna: Department
# [nan ' Research & Development ' ' Sales ' ' Human Resources ']
#
# --------------------
#
# Columna: DistanceFromHome
# [  6   1   4   2   3  22  25   9   7  23  10  12  14 -13  15   8 -42  28
#  -37   5  16 -35  26 -26  24  29 -25  17  21 -18 -10 -30 -27  20 -31 -29
#  -39  18 -21 -15  11  13 -14  19 -33 -34 -46 -36 -19  27 -12 -23 -45 -28
#  -47 -32 -24 -16 -22 -41 -49 -11 -48 -38 -20 -17 -43 -40 -44]
#
# --------------------
#
# Columna: Education
# [3 4 2 1 5]
#
# --------------------
#
# Columna: EducationField
# [nan 'Life Sciences' 'Technical Degree' 'Medical' 'Other' 'Marketing'
#  'Human Resources']
#
# --------------------
#
# Columna: employeecount
# [1]
#
# --------------------
#
# Columna: employeenumber
# ['162,0' '259,0' '319,0' ... '2012,0' '2023,0' '2040,0']
#
# --------------------
#
# Columna: EnvironmentSatisfaction
# [ 1  3  4  2 42 37 35 25 27 31 39 21 15 14 33 19 12 13 28 47 36 29 24 46
#  16 22 41 49 11 48 18 10 45 38 17 20 26 43]
#
# --------------------
#
# Columna: Gender
# [0 1]
#
# --------------------
#
# Columna: HourlyRate
# ['51' '65' '58' '82' '45' '99' '91' '64' '55' '68' '49' '61' '79' '31'
#  '69' '48' '80' '74' '98' '59' '33' '56' '66' '57' '53' '87' '81' '84'
#  '32' '41' '92' '47' 'Not Available' '43' '86' '30' '42' '88' '96' '67'
#  '62' '72' '78' '89' '52' '50' '90' '37' '94' '76' '60' '46' '83' '100'
#  '40' '97' '54' '75' '39' '85' '63' '44' '93' '36' '35' '73' '71' '70'
#  '38' '77' '95' '34']
#
# --------------------
#
# Columna: JobInvolvement
# [3 2 4 1]
#
# --------------------
#
# Columna: JobLevel
# [5 4 3 2 1]
#
# --------------------
#
# Columna: JobRole
# [' resEArch DIREcToR ' ' ManAGeR ' ' ManaGER ' ... ' sAlES ExECUTivE '
#  ' SaLes ExecUtIVe ' ' mAnUfactURInG DiRECTOr ']
#
# --------------------
#
# Columna: JobSatisfaction
# [3 4 1 2]
#
# --------------------
#
# Columna: MaritalStatus
# [nan 'Married' 'Divorced' 'Single' 'divorced' 'Marreid']
#
# --------------------
#
# Columna: MonthlyIncome
# ['19537,0' '19999,0' '19232,0' '17169,0' nan '17174,0' '16595,0' '19973,0'
#  '13402,0' '13206,0' '19545,0' '18041,0' '19246,0' '10748,0' '16752,0'
#  '6201,0' '19845,0' '4001,0' '10447,0' '16064,0' '3210,0' '10266,0'
#  '10475,0' '6162,0' '4721,0' '4615,0' '16959,0' '10306,0' '5406,0'
#  '5902,0' '10855,0' '5914,0' '6646,0' '13973,0' '13320,0' '6687,0'
#  '4735,0' '13872,0' '19045,0' '16015,0' '9613,0' '11510,0' '4306,0'
#  '17046,0' '5067,0' '3692,0' '19847,0' '2308,0' '5747,0' '10422,0'
#  '6347,0' '2348,0' '3072,0' '12490,0' '8020,0' '17068,0' '8943,0'
#  '19272,0' '5577,0' '2691,0' '7403,0' '8823,0' '3579,0' '17779,0'
#  '18213,0' '13577,0' '19190,0' '17123,0' '19187,0' '10008,0' '7988,0'
#  '7083,0' '4723,0' '3407,0' '2929,0' '12031,0' '15427,0' '5126,0' '9619,0'
#  '5010,0' '19033,0' '10400,0' '2793,0' '5674,0' '19197,0' '8412,0'
#  '3348,0' '5309,0' '7654,0' '12808,0' '6586,0' '2519,0' '17099,0'
#  '13120,0' '3131,0' '4444,0' '6674,0' '9852,0' '17861,0' '7446,0'
#  '13757,0' '16598,0' '4285,0' '10124,0' '9714,0' '9924,0' '11245,0'
#  '3069,0' '9241,0' '6472,0' '3055,0' '8321,0' '3143,0' '8578,0' '4197,0'
#  '9888,0' '13341,0' '5677,0' '2909,0' '9526,0' '6825,0' '4424,0' '5441,0'
#  '6074,0' '6146,0' '6172,0' '4668,0' '5605,0' '4319,0' '3564,0' '6261,0'
#  '6804,0' '19436,0' '5828,0' '2455,0' '5055,0' '4682,0' '5257,0' '2119,0'
#  '5974,0' '3034,0' '13212,0' '8392,0' '4051,0' '4805,0' '2741,0' '5337,0'
#  '9434,0' '5396,0' '11159,0' '4960,0' '8793,0' '19189,0' '2216,0'
#  '11713,0' '5304,0' '11103,0' '6632,0' '7587,0' '4335,0' '5980,0' '4244,0'
#  '5228,0' '2700,0' '2366,0' '2329,0' '4294,0' '6725,0' '10325,0' '4447,0'
#  '10845,0' '5472,0' '6385,0' '7525,0' '3660,0' '8740,0' '13499,0' '3491,0'
#  '5220,0' '10252,0' '19740,0' '6209,0' '7094,0' '4534,0' '8500,0' '4639,0'
#  '5363,0' '4081,0' '3578,0' '17328,0' '10793,0' '10851,0' '10466,0'
#  '2362,0' '6439,0' '5769,0' '4385,0' '4066,0' '5206,0' '2655,0' '2570,0'
#  '4502,0' '4968,0' '5147,0' '2718,0' '3539,0' '5468,0' '5813,0' '9667,0'
#  '5154,0' '5675,0' '7314,0' '5098,0' '13570,0' '6712,0' '9991,0' '10248,0'
#  '10938,0' '2593,0' '11878,0' '8095,0' '16856,0' '4537,0' '17924,0'
#  '4014,0' '12742,0' '3376,0' '10482,0' '4249,0' '6549,0' '14411,0'
#  '19586,0' '8237,0' '3211,0' '16704,0' '4774,0' '4568,0' '5993,0' '6499,0'
#  '3452,0' '6397,0' '2725,0' '3622,0' '6180,0' '6274,0' '4381,0' '2559,0'
#  '5488,0' '2514,0' '3196,0' '3420,0' '4087,0' '5368,0' '12936,0' '4221,0'
#  '4963,0' '4200,0' '5006,0' '7639,0' '6502,0' '13525,0' '6349,0' '6380,0'
#  '3102,0' '4556,0' '4230,0' '4859,0' '6322,0' '10761,0' '2973,0' '5204,0'
#  '17399,0' '16885,0' '4323,0' '5155,0' '2936,0' '18789,0' '4883,0'
#  '2029,0' '2996,0' '9278,0' '4162,0' '8853,0' '4876,0' '2141,0' '7756,0'
#  '3936,0' '6842,0' '3989,0' '4930,0' '3702,0' '2705,0' '4448,0' '2379,0'
#  '5487,0' '2810,0' '8938,0' '9936,0' '5454,0' '18740,0' '5473,0' '13503,0'
#  '13549,0' '18172,0' '2774,0' '9439,0' '5265,0' '3815,0' '2389,0' '4000,0'
#  '17584,0' '5661,0' '4869,0' '4649,0' '10496,0' '2768,0' '3408,0' '3755,0'
#  '2187,0' '4258,0' '5326,0' '5485,0' '2782,0' '17639,0' '6062,0' '6288,0'
#  '3424,0' '4194,0' '2532,0' '5666,0' '13726,0' '4107,0' '3597,0' '4115,0'
#  '6272,0' '2517,0' '3904,0' '9204,0' '4373,0' '2064,0' '2430,0' '4877,0'
#  '3760,0' '2013,0' '2974,0' '2766,0' '3377,0' '4213,0' '6513,0' '4284,0'
#  '2226,0' '5561,0' '2144,0' '5373,0' '2897,0' '5321,0' '5410,0' '4850,0'
#  '2001,0' '4404,0' '3944,0' '2960,0' '18947,0' '6465,0' '2683,0' '2014,0'
#  '3441,0' '13664,0' '5021,0' '18844,0' '4739,0' '10650,0' '4317,0'
#  '2024,0' '3058,0' '3929,0' '4425,0' '2328,0' '2657,0' '5940,0' '2622,0'
#  '3212,0' '2911,0' '6931,0' '2176,0' '3230,0' '18665,0' '2789,0' '6410,0'
#  '4941,0' '3983,0' '2904,0' '2696,0' '2174,0' '6755,0' '10965,0' '2543,0'
#  '19406,0' '6538,0' '2258,0' '2218,0' '2654,0' '11935,0' '2546,0' '3894,0'
#  '4262,0' '10527,0' '2400,0' '3681,0' '3447,0' '19513,0' '2659,0' '8847,0'
#  '2045,0' '4851,0' '8120,0' '4577,0' '5405,0' '3708,0' '13770,0' '2297,0'
#  '2450,0' '4342,0' '2572,0' '6500,0' '3149,0' '5324,0' '4382,0' '2553,0'
#  '5933,0' '4403,0' '10934,0' '2022,0' '4256,0' '3580,0' '2899,0' '5562,0'
#  '2377,0' '2404,0' '2799,0' '2811,0' '4377,0' '4240,0' '4227,0' '3917,0'
#  '4969,0' '2042,0' '2821,0' '9957,0' '2207,0' '2070,0' '2791,0' '8224,0'
#  '2610,0' '5731,0' '2539,0' '2376,0' '19081,0' '2743,0' '4538,0' '3867,0'
#  '2080,0' '2096,0' '4627,0' '2302,0' '5071,0' '10596,0' '5467,0' '2394,0'
#  '3629,0' '9362,0' '3229,0' '16422,0' '5647,0' '4400,0' '2066,0' '5486,0'
#  '3162,0' '6651,0' '4898,0' '3180,0' '11244,0' '4069,0' '6392,0' '4855,0'
#  '3312,0' '3117,0' '15202,0' '2580,0' '2166,0' '4374,0' '5505,0' '2587,0'
#  '15972,0' '2305,0' '3433,0' '3477,0' '3907,0' '3445,0' '2760,0' '6294,0'
#  '13116,0' '3591,0' '2105,0' '3902,0' '2662,0' '2062,0' '5507,0' '8103,0'
#  '3978,0' '5399,0' '10448,0' '4440,0' '2660,0' '3375,0' '2269,0' '4787,0'
#  '2809,0' '10854,0' '2571,0' '6142,0' '2496,0' '3419,0' '2501,0' '2566,0'
#  '3920,0' '13964,0' '6540,0' '2244,0' '16184,0' '4233,0' '14814,0'
#  '17159,0' '2318,0' '3617,0' '2684,0' '19237,0' '4422,0' '2552,0' '2678,0'
#  '5171,0' '11916,0' '9380,0' '5878,0' '2468,0' '4127,0' '2148,0' '3886,0'
#  '6667,0' '2090,0' '2086,0' '1951,0' '3022,0' '9724,0' '3388,0' '3038,0'
#  '2322,0' '2926,0' '4505,0' '2835,0' '6553,0' '6673,0' '13591,0' '2177,0'
#  '19517,0' '19202,0' '10048,0' '2723,0' '6644,0' '3161,0' '1420,0'
#  '1200,0' '5238,0' '9985,0' '15992,0' '2370,0' '6781,0' '6653,0' '2851,0'
#  '5258,0' '2476,0' '2285,0' '3448,0' '4558,0' '1702,0' '2564,0' '5070,0'
#  '3780,0' '9824,0' '1878,0' '2340,0' '2127,0' '2033,0' '9602,0' '16627,0'
#  '2083,0' '1009,0' '7861,0' '2642,0' '5121,0' '2694,0' '5094,0' '2274,0'
#  '2314,0' '2380,0' '2008,0' '10552,0' '2259,0' '2413,0' '2121,0' '2479,0'
#  '13194,0' '4163,0' '2600,0' '18303,0' '4777,0' '1052,0' '2461,0' '2596,0'
#  '4728,0' '7351,0' '4766,0' '2827,0' '2853,0' '2290,0' '2107,0' '2210,0'
#  '13191,0' '18265,0' '1118,0' '2372,0' '2838,0' '18061,0' '1611,0'
#  '4768,0' '1274,0' '2561,0' '1563,0' '6388,0' '8376,0' '4841,0' '2074,0'
#  '2972,0' '6815,0' '2690,0' '17567,0' '1569,0' '4187,0' '3306,0' '1393,0'
#  '10883,0' '2862,0' '6735,0' '9756,0' '5294,0' '2437,0' '4071,0' '2956,0'
#  '4648,0' '2804,0' '2439,0' '2856,0' '2933,0' '1091,0' '5151,0' '2863,0'
#  '2858,0' '1129,0' '19431,0']
#
# --------------------
#
# Columna: MonthlyRate
# [ 6462  5678  4933 ... 15302 26956 16642]
#
# --------------------
#
# Columna: NUMCOMPANIESWORKED
# [7 0 1 3 2 4 8 9 5 6]
#
# --------------------
#
# Columna: Over18
# ['Y' nan]
#
# --------------------
#
# Columna: OverTime
# ['No' nan 'Yes']
#
# --------------------
#
# Columna: PercentSalaryHike
# [13 14 11 19 12 25 16 17 22 23 20 15 21 24 18]
#
# --------------------
#
# Columna: PerformanceRating
# ['3,0' '4,0' nan]
#
# --------------------
#
# Columna: RelationshipSatisfaction
# [3 1 4 2]
#
# --------------------
#
# Columna: StandardHours
# [nan '80,0']
#
# --------------------
#
# Columna: StockOptionLevel
# [0 1 2 3]
#
# --------------------
#
# Columna: TOTALWORKINGYEARS
# [nan '34,0' '22,0' '28,0' '20,0' '21,0' '33,0' '40,0' '18,0' '25,0' '15,0'
#  '17,0' '26,0' '16,0' '24,0' '14,0' '23,0' '27,0' '19,0' '11,0' '38,0'
#  '37,0' '13,0' '12,0' '29,0' '10,0' '36,0' '35,0' '9,0' '31,0' '32,0'
#  '8,0' '7,0' '30,0' '6,0' '5,0' '4,0' '3,0' '2,0' '1,0' '0,0']
#
# --------------------
#
# Columna: TrainingTimesLastYear
# [5 3 2 0 1 4 6]
#
# --------------------
#
# Columna: WORKLIFEBALANCE
# ['3,0' nan '2,0' '4,0' '1,0']
#
# --------------------
#
# Columna: YearsAtCompany
# [20 33 22 19 21 18 24 31 26 16 23 15 17 32 14 13 25 12 11 37 40 36 27 29
#  10  9 30  8  7 34  6  5  4  2  3  1  0]
#
# --------------------
#
# Columna: YearsInCurrentRole
# [nan '13,0' '12,0' '11,0' '7,0' '6,0' '4,0' '3,0' '2,0' '1,0' '0,0']
#
# --------------------
#
# Columna: YearsSinceLastPromotion
# [15 11  5  2  4  7  0  1 13 14  8 12  3  6 10  9]
#
# --------------------
#
# Columna: YEARSWITHCURRMANAGER
# [15  9  6  8  7 11 10 12  4  0  5 17  2 14  1 13  3 16]
#
# --------------------
#
# Columna: SameAsMonthlyIncome
# ['19537,0' '19999,0' '19232,0' '17169,0' nan '17174,0' '16595,0' '19973,0'
#  '13402,0' '13206,0' '19545,0' '18041,0' '19246,0' '10748,0' '16752,0'
#  '6201,0' '19845,0' '4001,0' '10447,0' '16064,0' '3210,0' '10266,0'
#  '10475,0' '6162,0' '4721,0' '4615,0' '16959,0' '10306,0' '5406,0'
#  '5902,0' '10855,0' '5914,0' '6646,0' '13973,0' '13320,0' '6687,0'
#  '4735,0' '13872,0' '19045,0' '16015,0' '9613,0' '11510,0' '4306,0'
#  '17046,0' '5067,0' '3692,0' '19847,0' '2308,0' '5747,0' '10422,0'
#  '6347,0' '2348,0' '3072,0' '12490,0' '8020,0' '17068,0' '8943,0'
#  '19272,0' '5577,0' '2691,0' '7403,0' '8823,0' '3579,0' '17779,0'
#  '18213,0' '13577,0' '19190,0' '17123,0' '19187,0' '10008,0' '7988,0'
#  '7083,0' '4723,0' '3407,0' '2929,0' '12031,0' '15427,0' '5126,0' '9619,0'
#  '5010,0' '19033,0' '10400,0' '2793,0' '5674,0' '19197,0' '8412,0'
#  '3348,0' '5309,0' '7654,0' '12808,0' '6586,0' '2519,0' '17099,0'
#  '13120,0' '3131,0' '4444,0' '6674,0' '9852,0' '17861,0' '7446,0'
#  '13757,0' '16598,0' '4285,0' '10124,0' '9714,0' '9924,0' '11245,0'
#  '3069,0' '9241,0' '6472,0' '3055,0' '8321,0' '3143,0' '8578,0' '4197,0'
#  '9888,0' '13341,0' '5677,0' '2909,0' '9526,0' '6825,0' '4424,0' '5441,0'
#  '6074,0' '6146,0' '6172,0' '4668,0' '5605,0' '4319,0' '3564,0' '6261,0'
#  '6804,0' '19436,0' '5828,0' '2455,0' '5055,0' '4682,0' '5257,0' '2119,0'
#  '5974,0' '3034,0' '13212,0' '8392,0' '4051,0' '4805,0' '2741,0' '5337,0'
#  '9434,0' '5396,0' '11159,0' '4960,0' '8793,0' '19189,0' '2216,0'
#  '11713,0' '5304,0' '11103,0' '6632,0' '7587,0' '4335,0' '5980,0' '4244,0'
#  '5228,0' '2700,0' '2366,0' '2329,0' '4294,0' '6725,0' '10325,0' '4447,0'
#  '10845,0' '5472,0' '6385,0' '7525,0' '3660,0' '8740,0' '13499,0' '3491,0'
#  '5220,0' '10252,0' '19740,0' '6209,0' '7094,0' '4534,0' '8500,0' '4639,0'
#  '5363,0' '4081,0' '3578,0' '17328,0' '10793,0' '10851,0' '10466,0'
#  '2362,0' '6439,0' '5769,0' '4385,0' '4066,0' '5206,0' '2655,0' '2570,0'
#  '4502,0' '4968,0' '5147,0' '2718,0' '3539,0' '5468,0' '5813,0' '9667,0'
#  '5154,0' '5675,0' '7314,0' '5098,0' '13570,0' '6712,0' '9991,0' '10248,0'
#  '10938,0' '2593,0' '11878,0' '8095,0' '16856,0' '4537,0' '17924,0'
#  '4014,0' '12742,0' '3376,0' '10482,0' '4249,0' '6549,0' '14411,0'
#  '19586,0' '8237,0' '3211,0' '16704,0' '4774,0' '4568,0' '5993,0' '6499,0'
#  '3452,0' '6397,0' '2725,0' '3622,0' '6180,0' '6274,0' '4381,0' '2559,0'
#  '5488,0' '2514,0' '3196,0' '3420,0' '4087,0' '5368,0' '12936,0' '4221,0'
#  '4963,0' '4200,0' '5006,0' '7639,0' '6502,0' '13525,0' '6349,0' '6380,0'
#  '3102,0' '4556,0' '4230,0' '4859,0' '6322,0' '10761,0' '2973,0' '5204,0'
#  '17399,0' '16885,0' '4323,0' '5155,0' '2936,0' '18789,0' '4883,0'
#  '2029,0' '2996,0' '9278,0' '4162,0' '8853,0' '4876,0' '2141,0' '7756,0'
#  '3936,0' '6842,0' '3989,0' '4930,0' '3702,0' '2705,0' '4448,0' '2379,0'
#  '5487,0' '2810,0' '8938,0' '9936,0' '5454,0' '18740,0' '5473,0' '13503,0'
#  '13549,0' '18172,0' '2774,0' '9439,0' '5265,0' '3815,0' '2389,0' '4000,0'
#  '17584,0' '5661,0' '4869,0' '4649,0' '10496,0' '2768,0' '3408,0' '3755,0'
#  '2187,0' '4258,0' '5326,0' '5485,0' '2782,0' '17639,0' '6062,0' '6288,0'
#  '3424,0' '4194,0' '2532,0' '5666,0' '13726,0' '4107,0' '3597,0' '4115,0'
#  '6272,0' '2517,0' '3904,0' '9204,0' '4373,0' '2064,0' '2430,0' '4877,0'
#  '3760,0' '2013,0' '2974,0' '2766,0' '3377,0' '4213,0' '6513,0' '4284,0'
#  '2226,0' '5561,0' '2144,0' '5373,0' '2897,0' '5321,0' '5410,0' '4850,0'
#  '2001,0' '4404,0' '3944,0' '2960,0' '18947,0' '6465,0' '2683,0' '2014,0'
#  '3441,0' '13664,0' '5021,0' '18844,0' '4739,0' '10650,0' '4317,0'
#  '2024,0' '3058,0' '3929,0' '4425,0' '2328,0' '2657,0' '5940,0' '2622,0'
#  '3212,0' '2911,0' '6931,0' '2176,0' '3230,0' '18665,0' '2789,0' '6410,0'
#  '4941,0' '3983,0' '2904,0' '2696,0' '2174,0' '6755,0' '10965,0' '2543,0'
#  '19406,0' '6538,0' '2258,0' '2218,0' '2654,0' '11935,0' '2546,0' '3894,0'
#  '4262,0' '10527,0' '2400,0' '3681,0' '3447,0' '19513,0' '2659,0' '8847,0'
#  '2045,0' '4851,0' '8120,0' '4577,0' '5405,0' '3708,0' '13770,0' '2297,0'
#  '2450,0' '4342,0' '2572,0' '6500,0' '3149,0' '5324,0' '4382,0' '2553,0'
#  '5933,0' '4403,0' '10934,0' '2022,0' '4256,0' '3580,0' '2899,0' '5562,0'
#  '2377,0' '2404,0' '2799,0' '2811,0' '4377,0' '4240,0' '4227,0' '3917,0'
#  '4969,0' '2042,0' '2821,0' '9957,0' '2207,0' '2070,0' '2791,0' '8224,0'
#  '2610,0' '5731,0' '2539,0' '2376,0' '19081,0' '2743,0' '4538,0' '3867,0'
#  '2080,0' '2096,0' '4627,0' '2302,0' '5071,0' '10596,0' '5467,0' '2394,0'
#  '3629,0' '9362,0' '3229,0' '16422,0' '5647,0' '4400,0' '2066,0' '5486,0'
#  '3162,0' '6651,0' '4898,0' '3180,0' '11244,0' '4069,0' '6392,0' '4855,0'
#  '3312,0' '3117,0' '15202,0' '2580,0' '2166,0' '4374,0' '5505,0' '2587,0'
#  '15972,0' '2305,0' '3433,0' '3477,0' '3907,0' '3445,0' '2760,0' '6294,0'
#  '13116,0' '3591,0' '2105,0' '3902,0' '2662,0' '2062,0' '5507,0' '8103,0'
#  '3978,0' '5399,0' '10448,0' '4440,0' '2660,0' '3375,0' '2269,0' '4787,0'
#  '2809,0' '10854,0' '2571,0' '6142,0' '2496,0' '3419,0' '2501,0' '2566,0'
#  '3920,0' '13964,0' '6540,0' '2244,0' '16184,0' '4233,0' '14814,0'
#  '17159,0' '2318,0' '3617,0' '2684,0' '19237,0' '4422,0' '2552,0' '2678,0'
#  '5171,0' '11916,0' '9380,0' '5878,0' '2468,0' '4127,0' '2148,0' '3886,0'
#  '6667,0' '2090,0' '2086,0' '1951,0' '3022,0' '9724,0' '3388,0' '3038,0'
#  '2322,0' '2926,0' '4505,0' '2835,0' '6553,0' '6673,0' '13591,0' '2177,0'
#  '19517,0' '19202,0' '10048,0' '2723,0' '6644,0' '3161,0' '1420,0'
#  '1200,0' '5238,0' '9985,0' '15992,0' '2370,0' '6781,0' '6653,0' '2851,0'
#  '5258,0' '2476,0' '2285,0' '3448,0' '4558,0' '1702,0' '2564,0' '5070,0'
#  '3780,0' '9824,0' '1878,0' '2340,0' '2127,0' '2033,0' '9602,0' '16627,0'
#  '2083,0' '1009,0' '7861,0' '2642,0' '5121,0' '2694,0' '5094,0' '2274,0'
#  '2314,0' '2380,0' '2008,0' '10552,0' '2259,0' '2413,0' '2121,0' '2479,0'
#  '13194,0' '4163,0' '2600,0' '18303,0' '4777,0' '1052,0' '2461,0' '2596,0'
#  '4728,0' '7351,0' '4766,0' '2827,0' '2853,0' '2290,0' '2107,0' '2210,0'
#  '13191,0' '18265,0' '1118,0' '2372,0' '2838,0' '18061,0' '1611,0'
#  '4768,0' '1274,0' '2561,0' '1563,0' '6388,0' '8376,0' '4841,0' '2074,0'
#  '2972,0' '6815,0' '2690,0' '17567,0' '1569,0' '4187,0' '3306,0' '1393,0'
#  '10883,0' '2862,0' '6735,0' '9756,0' '5294,0' '2437,0' '4071,0' '2956,0'
#  '4648,0' '2804,0' '2439,0' '2856,0' '2933,0' '1091,0' '5151,0' '2863,0'
#  '2858,0' '1129,0' '19431,0']
#
# --------------------
#
# Columna: DateBirth
# [1972 1971 1981 1976 1977 1975 1964 1982 1967 1985 1968 1983 1965 1988
#  1978 1990 1987 1989 1970 1980 1963 1991 1986 1974 1984 1973 1979 1993
#  1994 1992 1969 1966 1996 1995 1997 1998 1999 2000 2001 2002 2003 2004
#  2005]
#
# --------------------
#
# Columna: Salary
# ['1000000000$']
#
# --------------------
#
# Columna: RoleDepartament
# [nan ' ManaGER  -  Research & Development '
#  ' MANAger  -  Research & Development '
#  ' heaLtHcArE repResENtATiVe  -  Research & Development '
#  ' saLEs exEcutIVe  -  Sales ' ' Sales ExECuTIVe  -  Sales '
#  ' heALthCArE RePResEntaTIVe  -  Research & Development '
#  ' lABORAtOry tECHnIcIan  -  Research & Development '
#  ' ManufactUrINg DiReCTOr  -  Research & Development '
#  ' SaleS eXEcUtIVE  -  Sales '
#  ' HEaLthcaRe rEprEsEnTAtiVe  -  Research & Development '
#  ' rESeArCH sCientIST  -  Research & Development '
#  ' healTHCAre rePREseNtATiVE  -  Research & Development '
#  ' mANaGer  -  Research & Development '
#  ' HEAltHCaRe REPreseNTatIve  -  Research & Development '
#  ' SaLeS eXECUTivE  -  Sales '
#  ' reSeARCH SCIEnTiST  -  Research & Development '
#  ' ReSearch DiRecTOR  -  Research & Development '
#  ' resEaRCh SciEnTist  -  Research & Development '
#  ' hUmaN REsoUrCes  -  Human Resources '
#  ' manAgER  -  Research & Development ' ' SaLES eXeCUtIVE  -  Sales '
#  ' reSEarCH scIentISt  -  Research & Development '
#  ' ReSeARCh DiRECtor  -  Research & Development ' ' MaNAgeR  -  Sales '
#  ' RESEArCH sCIenTIst  -  Research & Development '
#  ' hUMAn reSoUrCES  -  Human Resources '
#  ' HUmAN rESOuRceS  -  Human Resources ' ' SaleS EXeCuTivE  -  Sales '
#  ' ReSeARch scIENTISt  -  Research & Development '
#  ' LaBoRaTorY TeChNicIAn  -  Research & Development '
#  ' ManUfaCTUriNg dIReCtor  -  Research & Development '
#  ' saLES ExECuTIVe  -  Sales '
#  ' RESEaRch SCIEntISt  -  Research & Development '
#  ' mAnUFaCtUrinG diReCtor  -  Research & Development '
#  ' maNUFAcTURING direCTOr  -  Research & Development '
#  ' labOraTORy techNicIan  -  Research & Development '
#  ' SAlEs ExeCUtive  -  Sales '
#  ' MANUFACturING DIRecToR  -  Research & Development '
#  ' Sales eXECuTIvE  -  Sales '
#  ' mANUfaCTuRiNG DiRECtOr  -  Research & Development '
#  ' ManUFACtURiNg DiRECTOr  -  Research & Development '
#  ' ResEARcH DiReCToR  -  Research & Development '
#  ' MANAgER  -  Research & Development '
#  ' labORATORY TechnIcIaN  -  Research & Development '
#  ' MaNUfacTurINg DiReCTor  -  Research & Development '
#  ' ReSEaRcH sciENTIST  -  Research & Development '
#  ' rESEARCh dIrEcTOr  -  Research & Development '
#  ' MANUfACTuRinG diRecTOR  -  Research & Development '
#  ' HeaLThCArE REpRESENTAtIVe  -  Research & Development '
#  ' LABOraTory TecHnIciaN  -  Research & Development '
#  ' sales rEprESEntAtIvE  -  Sales '
#  ' mANuFacTurinG DirECtoR  -  Research & Development '
#  ' lABorATOrY TeChnICIan  -  Research & Development '
#  ' RESEarCh SCIEnTiST  -  Research & Development '
#  ' SALes exEcuTIVe  -  Sales '
#  ' REseARCH DirectOr  -  Research & Development '
#  ' sAlES EXEcUtIVe  -  Sales '
#  ' lABoraToRY teCHnIcIaN  -  Research & Development '
#  ' LaBorATORy tEChnICiaN  -  Research & Development '
#  ' sales ExecutIvE  -  Sales ' ' sAles exECUtiVe  -  Sales '
#  ' SALEs eXecuTiVE  -  Sales ' ' SaleS executIVE  -  Sales '
#  ' rEsEArCH sCIeNTIST  -  Research & Development '
#  ' reSEArch SCIEntIsT  -  Research & Development '
#  ' rESeArCh DIrEctor  -  Research & Development '
#  ' saLES ExECUtiVe  -  Sales '
#  ' LaboRATory tEchNICIAn  -  Research & Development '
#  ' SAlEs exECUtIVe  -  Sales ' ' salEs eXECuTivE  -  Sales '
#  ' ReseaRch scIenTisT  -  Research & Development '
#  ' LaBoraTORY teCHNiCIaN  -  Research & Development '
#  ' sALEs ExeCuTive  -  Sales '
#  ' heALtHCARE rePResENtAtivE  -  Research & Development '
#  ' ManAgEr  -  Research & Development '
#  ' laboRAtORy TecHnICiAN  -  Research & Development '
#  ' ReSeARCH diRECtoR  -  Research & Development '
#  ' LAborAtOry TEchniCIAn  -  Research & Development '
#  ' SaLeS eXECutiVE  -  Sales ' ' SalEs eXECuTive  -  Sales '
#  ' rESeaRCH DIReCToR  -  Research & Development '
#  ' mANAGeR  -  Human Resources ' ' saLeS exECUtive  -  Sales '
#  ' maNuFAcTURInG DIReCtoR  -  Research & Development '
#  ' LABORaTorY TEChNIcIAN  -  Research & Development '
#  ' hEalTHcARe RePrEseNTATive  -  Research & Development '
#  ' mANuFActuring DireCtOR  -  Research & Development '
#  ' MaNagEr  -  Research & Development ' ' SaLeS exeCuTIVe  -  Sales '
#  ' lAboRaTory tECHNIciAN  -  Research & Development '
#  ' saLes eXECUTIVe  -  Sales ' ' saLes EXEcuTiVe  -  Sales '
#  ' mAnaGeR  -  Research & Development '
#  ' HEALThCaRe rePResEnTaTivE  -  Research & Development '
#  ' mAnAgEr  -  Research & Development '
#  ' MaNageR  -  Research & Development '
#  ' HeAlThCarE rEpreSentatiVe  -  Research & Development '
#  ' HUMAN ResoURCeS  -  Human Resources '
#  ' huMAn ResOurces  -  Human Resources '
#  ' mANUfacTURiNG dIRectOR  -  Research & Development '
#  ' saLES eXEcUTiVE  -  Sales '
#  ' labORaTORY teChNIcIaN  -  Research & Development '
#  ' saLes eXeCUTivE  -  Sales ' ' Sales exECutIVE  -  Sales '
#  ' saleS eXEcuTIvE  -  Sales ' ' SALes ExeCUtive  -  Sales '
#  ' reSearCH SCieNtIst  -  Research & Development '
#  ' HEALThcaRe RePresENtaTiVE  -  Research & Development '
#  ' rEsEARch sCientIST  -  Research & Development '
#  ' HealthcARE RePreSENtAtiVe  -  Research & Development '
#  ' ResEArch ScieNTiST  -  Research & Development '
#  ' labORaTORy TecHniciAN  -  Research & Development '
#  ' SalEs exECUTIvE  -  Sales '
#  ' LabOrATory TEChNICiaN  -  Research & Development '
#  ' reSeArcH scieNtist  -  Research & Development '
#  ' maNuFAcTUring DIrecToR  -  Research & Development '
#  ' ResEARCh DIRECtoR  -  Research & Development '
#  ' SaLes exECutIVe  -  Sales ' ' SAleS eXecuTIVe  -  Sales '
#  ' manAGER  -  Sales '
#  ' LaBOrATORy teCHnIciaN  -  Research & Development '
#  ' SAlES ExecuTIVe  -  Sales ' ' salES exEcUtiVE  -  Sales '
#  ' SAlEs ExECUTIVe  -  Sales '
#  ' HEaLTHcaRE rePReseNtaTIvE  -  Research & Development '
#  ' sAles eXEcUtIve  -  Sales '
#  ' laBoraTorY tEChnICiaN  -  Research & Development '
#  ' MANufacTURIng diREcTOr  -  Research & Development '
#  ' REsearch scIENtist  -  Research & Development '
#  ' heaLtHcARe RePReSENtaTIve  -  Research & Development '
#  ' lAbOrAtorY techNiCiaN  -  Research & Development '
#  ' laboRaTOrY TEchniCIaN  -  Research & Development '
#  ' SAles ExECutIvE  -  Sales '
#  ' HeALtHCarE represEntAtIVe  -  Research & Development '
#  ' HEalThCaRe rEpReSENtatIVe  -  Research & Development '
#  ' HEalTHCare REPrEsEntATiVE  -  Research & Development '
#  ' LaBoRaToRY TEcHnIcian  -  Research & Development '
#  ' SAlES ExecutIve  -  Sales '
#  ' LaBOrAtory TECHNIciAN  -  Research & Development '
#  ' ReSeArch scIenTIsT  -  Research & Development '
#  ' SaLEs EXECutIVe  -  Sales '
#  ' rESEARch DiRector  -  Research & Development '
#  ' HEaltHcare rEPrEsEnTatIVe  -  Research & Development '
#  ' lABORatORY TeChNiCiAN  -  Research & Development '
#  ' LaBOratory TeChnICiAn  -  Research & Development '
#  ' maNAGer  -  Sales ' ' hUMAn rEsOuRCES  -  Human Resources '
#  ' sales ExeCUTiVE  -  Sales ' ' saLEs exeCUtiVe  -  Sales '
#  ' laBorAtORy TECHnicIaN  -  Research & Development '
#  ' ReSeaRch SCIEnTiSt  -  Research & Development '
#  ' rEsEArcH scIenTIst  -  Research & Development '
#  ' RESeArch dIREcToR  -  Research & Development '
#  ' saLes ExECutIVE  -  Sales '
#  ' REseARCh SCIenTIst  -  Research & Development '
#  ' sALEs exECuTiVe  -  Sales '
#  ' rEseArCh SCieNtiST  -  Research & Development '
#  ' lABoRAtoRY TecHnIcian  -  Research & Development '
#  ' researcH SciEntIST  -  Research & Development '
#  ' REseARCH ScIeNTIST  -  Research & Development '
#  ' sAles ExecUtive  -  Sales '
#  ' mAnUfaCTuRing DiRecTor  -  Research & Development '
#  ' SaLes exEcUtIvE  -  Sales '
#  ' ReseArCH scIenTIst  -  Research & Development '
#  ' ReseArch sCienTiST  -  Research & Development '
#  ' ReSEarcH SCiEnTISt  -  Research & Development '
#  ' laBORATORY tECHNiciAN  -  Research & Development '
#  ' rESeArCH sCIeNtISt  -  Research & Development '
#  ' humAN resoURCEs  -  Human Resources '
#  ' REseARCh scieNTIsT  -  Research & Development '
#  ' SaLeS REPRESENtATIvE  -  Sales '
#  ' ResEArch SciEntiST  -  Research & Development '
#  ' ReSEaRCh SCIEnTist  -  Research & Development '
#  ' hUmAn REsOurCES  -  Human Resources ' ' sALeS EXecuTIVe  -  Sales '
#  ' ReseArCh SciENTIsT  -  Research & Development '
#  ' sALes rEprESentAtIvE  -  Sales '
#  ' humaN reSOUrcEs  -  Human Resources '
#  ' lAboRatOrY TechNiCiAn  -  Research & Development '
#  ' HeAlthcaRE rEPrEseNTaTIVE  -  Research & Development '
#  ' sALeS eXecuTIvE  -  Sales ' ' SALeS RepREsEnTatiVe  -  Sales '
#  ' SaLes rePrESENTaTivE  -  Sales '
#  ' rESEaRch sCientISt  -  Research & Development '
#  ' laBORatoRy TEcHnician  -  Research & Development '
#  ' ReSeaRch SCIentiST  -  Research & Development '
#  ' RESEarch ScieNtIst  -  Research & Development '
#  ' sALeS RePresenTAtivE  -  Sales '
#  ' LABORAToRy tEchNICiAn  -  Research & Development '
#  ' ResEArch sCIEnTiST  -  Research & Development '
#  ' ReSEArcH sCIeNtist  -  Research & Development '
#  ' LaBoRaTory techNICIAN  -  Research & Development '
#  ' hEaLThcARE rEpresEntATiVE  -  Research & Development '
#  ' mANufActuRIng DirECTOR  -  Research & Development '
#  ' laBOraTOrY TecHNIcIan  -  Research & Development '
#  ' sALES ReprEsentatiVE  -  Sales '
#  ' laBoRatoRy TEChNICiAN  -  Research & Development '
#  ' ReSEarch scIeNTIsT  -  Research & Development '
#  ' researCh SCientIsT  -  Research & Development '
#  ' ReseaRch scIENTisT  -  Research & Development '
#  ' lAboRaToRY teChNICIan  -  Research & Development '
#  ' rEsEaRCh diReCtOR  -  Research & Development '
#  ' labORAtoRy tEcHNICIAN  -  Research & Development '
#  ' SAlES exeCutive  -  Sales '
#  ' hEalthCaRe reprEseNTaTiVe  -  Research & Development '
#  ' ManufacTURInG DIRECtOR  -  Research & Development '
#  ' sAles exEcUtIve  -  Sales '
#  ' reseARCh SCieNTisT  -  Research & Development '
#  ' reSEarcH scIENtISt  -  Research & Development '
#  ' reseArCH scIentISt  -  Research & Development '
#  ' MANuFaCturiNG dIRECTOR  -  Research & Development '
#  ' HuMan resoUrCes  -  Human Resources '
#  ' huMAn Resources  -  Human Resources ' ' Sales EXEcUTiVe  -  Sales '
#  ' reSEaRCH scIenTisT  -  Research & Development '
#  ' sales rEpRESEnTatIve  -  Sales '
#  ' reseaRch DIrecTOr  -  Research & Development '
#  ' sALeS eXECutivE  -  Sales ' ' Human REsouRCeS  -  Human Resources '
#  ' rESeArcH sCientIST  -  Research & Development '
#  ' SAlES RepreSENtATiVe  -  Sales ' ' SAles execUTIve  -  Sales '
#  ' RESEArch SCIEnTISt  -  Research & Development '
#  ' labOrATOry TEchnIcIaN  -  Research & Development '
#  ' sALes ExEcUTIVe  -  Sales '
#  ' REsEARch sCIenTIsT  -  Research & Development '
#  ' RESeARch ScIeNtisT  -  Research & Development '
#  ' rEseARCH ScIeNtIST  -  Research & Development '
#  ' ManAGEr  -  Research & Development '
#  ' LaBoratory TECHnICIAn  -  Research & Development '
#  ' saLES exEcutivE  -  Sales '
#  ' LABorATory TecHnIcIaN  -  Research & Development '
#  ' HumAN REsourceS  -  Human Resources '
#  ' reseaRCh SCIentIst  -  Research & Development '
#  ' LaBOrAToRy teChNiciAn  -  Research & Development '
#  ' LaborAtorY Technician  -  Research & Development '
#  ' rEseaRCH sCIeNtiSt  -  Research & Development '
#  ' LABOrATOrY TEchnIcIAn  -  Research & Development '
#  ' ReSeARCh DireCtOr  -  Research & Development '
#  ' LaBORatORy tEchNiCian  -  Research & Development '
#  ' laBorATOrY TeChNIcIAn  -  Research & Development '
#  ' sALEs RePREsentaTive  -  Sales ' ' mAnageR  -  Sales '
#  ' rESEArcH SCiEntIst  -  Research & Development '
#  ' heAlThcaRe REprESeNTATive  -  Research & Development '
#  ' LABoratOry TeCHnIcIan  -  Research & Development '
#  ' hEAlthCarE rEpresenTATiVe  -  Research & Development '
#  ' HealTHcaRE rEPreSEntATive  -  Research & Development '
#  ' MaNUfActuRInG diREctOr  -  Research & Development '
#  ' saLes REPrEsentAtiVE  -  Sales '
#  ' LABorAtORy TEchnIciAn  -  Research & Development '
#  ' rEsEARcH ScieNTisT  -  Research & Development '
#  ' SalEs eXecuTive  -  Sales ' ' SaLeS EXEcUTiVe  -  Sales '
#  ' MaNufacTuRINg DirEcTor  -  Research & Development '
#  ' resEaRcH scIENTiSt  -  Research & Development '
#  ' SALes eXECuTIvE  -  Sales '
#  ' LabORatORy tEChnIcIAn  -  Research & Development '
#  ' LaBorAtOrY teCHNICIAn  -  Research & Development '
#  ' saLEs RePREsentAtiVE  -  Sales '
#  ' laBOrATORY TechNiCiAn  -  Research & Development '
#  ' sALes exECutIVe  -  Sales '
#  ' LabOraToRy technICiAN  -  Research & Development '
#  ' lAborAtORY TeCHNIciAN  -  Research & Development '
#  ' SAlES rePrESentaTIVe  -  Sales ' ' mANager  -  Research & Development '
#  ' HEAlThcARe rEPREseNtATIVe  -  Research & Development '
#  ' REsEArCH dIrECTOr  -  Research & Development '
#  ' rESeaRch SCIeNTIST  -  Research & Development '
#  ' SALEs REpRESentatIve  -  Sales ' ' SalES eXecUTiVE  -  Sales '
#  ' SaLes REPREseNtATive  -  Sales '
#  ' ReSeArch sCIEnTiSt  -  Research & Development '
#  ' sales REPReSeNtAtIVe  -  Sales ' ' sAles execUtIve  -  Sales '
#  ' LABOrATORy tEChNiCIaN  -  Research & Development '
#  ' hEalthCarE REPResEnTaTive  -  Research & Development '
#  ' mANagER  -  Research & Development ' ' sales repResENTaTiVE  -  Sales '
#  ' laboRAToRY tEChniCIAN  -  Research & Development '
#  ' resEaRcH sCIeNTisT  -  Research & Development '
#  ' maNuFAcTurING diREctOr  -  Research & Development '
#  ' mAnAger  -  Research & Development ' ' SALes eXEcUtiVe  -  Sales '
#  ' reSearCh SCiEnTist  -  Research & Development '
#  ' rESEARch SciENtiSt  -  Research & Development '
#  ' hUman ResourCeS  -  Human Resources ' ' SALES exeCUtIve  -  Sales '
#  ' ReseaRcH sCientiSt  -  Research & Development '
#  ' LAbORaTory tEcHnIciAN  -  Research & Development '
#  ' lABOraTOrY tecHniciaN  -  Research & Development '
#  ' sALeS exEcUtiVe  -  Sales ' ' salEs eXEcuTIvE  -  Sales '
#  ' SAleS ExEcuTiVE  -  Sales ' ' SaLeS exEcUTiVE  -  Sales '
#  ' ReSEArch scieNTiST  -  Research & Development '
#  ' reSEArCh sCieNtiST  -  Research & Development '
#  ' ReseaRCh dIRecTor  -  Research & Development '
#  ' SaLEs ExECUtiVE  -  Sales '
#  ' LAbORAToRy tEcHNICian  -  Research & Development '
#  ' sAleS EXECUtIvE  -  Sales ']
#
# --------------------
#
# Columna: NUMBERCHILDREN
# [nan]
#
# --------------------
#
# Columna: RemoteWork
# ['Yes' '1' 'False' '0' 'True']
#
# --------------------

# %% [markdown]
# ## Empezamos a limpiar los datos por columnas

# %%
# Convertimos todos los nombres de las columnas a minúsculas
data.columns = [column.lower() for column in data.columns]

# Modificamos los nombres de las columnas para mejor comprensión lectora
data.rename(columns={
    'unnamed: 0': 'id',
    'age': 'age',
    'attrition': 'attrition',
    'businesstravel': 'business_travel',
    'dailyrate': 'daily_rate',
    'department': 'department',
    'distancefromhome': 'distance_from_home',
    'education': 'education',
    'educationfield': 'education_field',
    'employeecount': 'employee_count',
    'employeenumber': 'employee_number',
    'environmentsatisfaction': 'environment_satisfaction',
    'gender': 'gender',
    'hourlyrate': 'hourly_rate',
    'jobinvolvement': 'job_involvement',
    'joblevel': 'job_level',
    'jobrole': 'job_role',
    'jobsatisfaction': 'job_satisfaction',
    'maritalstatus': 'marital_status',
    'monthlyincome': 'monthly_income',
    'monthlyrate': 'monthly_rate',
    'numcompaniesworked': 'num_companies_worked',
    'over18': 'over_18',
    'overtime': 'overtime',
    'percentsalaryhike': 'percent_salary_hike',
    'performancerating': 'performance_rating',
    'relationshipsatisfaction': 'relationship_satisfaction',
    'standardhours': 'standard_hours',
    'stockoptionlevel': 'stock_option_level',
    'totalworkingyears': 'total_working_years',
    'trainingtimeslastyear': 'training_times_last_year',
    'worklifebalance': 'work_life_balance',
    'yearsatcompany': 'years_at_company',
    'yearsincurrentrole': 'years_in_current_role',
    'yearssincelastpromotion': 'years_since_last_promotion',
    'yearswithcurrmanager': 'years_with_curr_manager',
    'sameasmonthlyincome': 'same_as_monthly_income',
    'datebirth': 'date_birth',
    'salary': 'salary',
    'roledepartament': 'role_department',
    'numberchildren': 'number_children',
    'remotework': 'remote_work'
}, inplace=True)

# %%
data
# Out:
#         id age attrition business_travel daily_rate                department  \
# 0        0  51        No             NaN     684,0$                       NaN
# 1        1  52        No             NaN     699,0$                       NaN
# 2        2  42        No   travel_rarely     532,0$   Research & Development
# 3        3  47        No   travel_rarely     359,0$                       NaN
# 4        4  46        No             NaN    1319,0$                       NaN
# ...    ...  ..       ...             ...        ...                       ...
# 1609  1609  36       Yes   travel_rarely     530,0$                       NaN
# 1610  1610  45        No      non-travel     805,0$                       NaN
# 1611  1611  39        No   travel_rarely     903,0$                       NaN
# 1612  1612  36        No      non-travel    1229,0$                       NaN
# 1613  1613  46        No             NaN     566,0$                       NaN
#
#       distance_from_home  education   education_field  employee_count  ...  \
# 0                      6          3               NaN               1  ...
# 1                      1          4     Life Sciences               1  ...
# 2                      4          2  Technical Degree               1  ...
# 3                      2          4           Medical               1  ...
# 4                      3          3  Technical Degree               1  ...
# ...                  ...        ...               ...             ...  ...
# 1609                   3          1     Life Sciences               1  ...
# 1610                   4          2               NaN               1  ...
# 1611                 -13          5               NaN               1  ...
# 1612                   8          4  Technical Degree               1  ...
# 1613                   7          2           Medical               1  ...
#
#      years_at_company  years_in_current_role  years_since_last_promotion  \
# 0                  20                    NaN                          15
# 1                  33                    NaN                          11
# 2                  22                    NaN                          11
# 3                  20                    NaN                           5
# 4                  19                    NaN                           2
# ...               ...                    ...                         ...
# 1609               16                    NaN                           3
# 1610                9                    NaN                           0
# 1611                8                    NaN                           0
# 1612                7                    NaN                           0
# 1613                8                    NaN                           0
#
#      years_with_curr_manager  same_as_monthly_income  date_birth       salary  \
# 0                         15                 19537,0        1972  1000000000$
# 1                          9                 19999,0        1971  1000000000$
# 2                         15                 19232,0        1981  1000000000$
# 3                          6                 17169,0        1976  1000000000$
# 4                          8                     NaN        1977  1000000000$
# ...                      ...                     ...         ...          ...
# 1609                       7                 10325,0        1987  1000000000$
# 1610                       8                  4447,0        1978  1000000000$
# 1611                       7                     NaN        1984  1000000000$
# 1612                       7                     NaN        1987  1000000000$
# 1613                       7                 10845,0        1977  1000000000$
#
#                            role_department number_children remote_work
# 0                                      NaN             NaN         Yes
# 1                                      NaN             NaN           1
# 2      ManaGER  -  Research & Development              NaN           1
# 3                                      NaN             NaN       False
# 4                                      NaN             NaN           0
# ...                                    ...             ...         ...
# 1609                                   NaN             NaN           0
# 1610                                   NaN             NaN           1
# 1611                                   NaN             NaN         Yes
# 1612                                   NaN             NaN        True
# 1613                                   NaN             NaN           0
#
# [1614 rows x 42 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1614 entries, 0 to 1613
# Data columns (total 42 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          1614 non-null   int64
#  1   age                         1614 non-null   object
#  2   attrition                   1614 non-null   object
#  3   business_travel             842 non-null    object
#  4   daily_rate                  1614 non-null   object
#  5   department                  302 non-null    object
#  6   distance_from_home          1614 non-null   int64
#  7   education                   1614 non-null   int64
#  8   education_field             869 non-null    object
#  9   employee_count              1614 non-null   int64
#  10  employee_number             1183 non-null   object
#  11  environment_satisfaction    1614 non-null   int64
#  12  gender                      1614 non-null   int64
#  13  hourly_rate                 1614 non-null   object
#  14  job_involvement             1614 non-null   int64
#  15  job_level                   1614 non-null   int64
#  16  job_role                    1614 non-null   object
#  17  job_satisfaction            1614 non-null   int64
#  18  marital_status              963 non-null    object
#  19  monthly_income              771 non-null    object
#  20  monthly_rate                1614 non-null   int64
#  21  num_companies_worked        1614 non-null   int64
#  22  over_18                     713 non-null    object
#  23  overtime                    938 non-null    object
#  24  percent_salary_hike         1614 non-null   int64
#  25  performance_rating          1419 non-null   object
#  26  relationship_satisfaction   1614 non-null   int64
#  27  standard_hours              419 non-null    object
#  28  stock_option_level          1614 non-null   int64
#  29  total_working_years         1088 non-null   object
#  30  training_times_last_year    1614 non-null   int64
#  31  work_life_balance           1506 non-null   object
#  32  years_at_company            1614 non-null   int64
#  33  years_in_current_role       34 non-null     object
#  34  years_since_last_promotion  1614 non-null   int64
#  35  years_with_curr_manager     1614 non-null   int64
#  36  same_as_monthly_income      771 non-null    object
#  37  date_birth                  1614 non-null   int64
#  38  salary                      1614 non-null   object
#  39  role_department             302 non-null    object
#  40  number_children             0 non-null      float64
#  41  remote_work                 1614 non-null   object
# dtypes: float64(1), int64(19), object(22)
# memory usage: 529.7+ KB

# %% [markdown]
# ## Decidimos entre Silvia P, Diana y Mábel, quitar columnas id_employee por no encontrarle utilidad

# %%
# Eliminar las columnas 'id' y 'same_as_monthly_income'
data_noid = data.drop(columns=["id", "same_as_monthly_income"])

# Mostrar el DataFrame resultante
data_noid
# Out:
#      age attrition business_travel daily_rate                department  \
# 0     51        No             NaN     684,0$                       NaN
# 1     52        No             NaN     699,0$                       NaN
# 2     42        No   travel_rarely     532,0$   Research & Development
# 3     47        No   travel_rarely     359,0$                       NaN
# 4     46        No             NaN    1319,0$                       NaN
# ...   ..       ...             ...        ...                       ...
# 1609  36       Yes   travel_rarely     530,0$                       NaN
# 1610  45        No      non-travel     805,0$                       NaN
# 1611  39        No   travel_rarely     903,0$                       NaN
# 1612  36        No      non-travel    1229,0$                       NaN
# 1613  46        No             NaN     566,0$                       NaN
#
#       distance_from_home  education   education_field  employee_count  \
# 0                      6          3               NaN               1
# 1                      1          4     Life Sciences               1
# 2                      4          2  Technical Degree               1
# 3                      2          4           Medical               1
# 4                      3          3  Technical Degree               1
# ...                  ...        ...               ...             ...
# 1609                   3          1     Life Sciences               1
# 1610                   4          2               NaN               1
# 1611                 -13          5               NaN               1
# 1612                   8          4  Technical Degree               1
# 1613                   7          2           Medical               1
#
#      employee_number  ...  work_life_balance  years_at_company  \
# 0              162,0  ...                3,0                20
# 1              259,0  ...                3,0                33
# 2              319,0  ...                NaN                22
# 3                NaN  ...                NaN                20
# 4                NaN  ...                3,0                19
# ...              ...  ...                ...               ...
# 1609           967,0  ...                3,0                16
# 1610           972,0  ...                2,0                 9
# 1611             NaN  ...                3,0                 8
# 1612           990,0  ...                3,0                 7
# 1613             NaN  ...                3,0                 8
#
#      years_in_current_role  years_since_last_promotion  \
# 0                      NaN                          15
# 1                      NaN                          11
# 2                      NaN                          11
# 3                      NaN                           5
# 4                      NaN                           2
# ...                    ...                         ...
# 1609                   NaN                           3
# 1610                   NaN                           0
# 1611                   NaN                           0
# 1612                   NaN                           0
# 1613                   NaN                           0
#
#       years_with_curr_manager date_birth       salary  \
# 0                          15       1972  1000000000$
# 1                           9       1971  1000000000$
# 2                          15       1981  1000000000$
# 3                           6       1976  1000000000$
# 4                           8       1977  1000000000$
# ...                       ...        ...          ...
# 1609                        7       1987  1000000000$
# 1610                        8       1978  1000000000$
# 1611                        7       1984  1000000000$
# 1612                        7       1987  1000000000$
# 1613                        7       1977  1000000000$
#
#                            role_department number_children  remote_work
# 0                                      NaN             NaN          Yes
# 1                                      NaN             NaN            1
# 2      ManaGER  -  Research & Development              NaN            1
# 3                                      NaN             NaN        False
# 4                                      NaN             NaN            0
# ...                                    ...             ...          ...
# 1609                                   NaN             NaN            0
# 1610                                   NaN             NaN            1
# 1611                                   NaN             NaN          Yes
# 1612                                   NaN             NaN         True
# 1613                                   NaN             NaN            0
#
# [1614 rows x 40 columns]

# %% [markdown]
# ### Lo que hay que cambiar de la 0 a la 21

# %% [markdown]
# - `daily_rate`: quitar símbolo `$` y convertir a `int`

# %%
# Aseguramos que los valores de 'daily_rate' son de tipo string
data_noid['daily_rate'] = data_noid['daily_rate'].astype(str)

# Lista de símbolos a eliminar en los valores de la columna
quitar_simbolos = [' ', '$']

# Itera sobre cada símbolo en la lista de símbolos a eliminar
for simbolo in quitar_simbolos:
    # Elimina el símbolo actual de todos los valores de la columna 'daily_rate'
    data_noid['daily_rate'] = data_noid['daily_rate'].str.replace(simbolo, '', regex=False)

# Rellena los valores NaN y los valores vacíos con '0'
data_noid['daily_rate'] = data_noid['daily_rate'].replace(['nan', ''], '0')

# Convierte la columna 'daily_rate' a tipo int, manejando errores
data_noid['daily_rate'] = pd.to_numeric(data_noid['daily_rate'], errors='coerce').fillna(0).astype(int)

# Muestra las primeras filas del DataFrame para verificar que los valores de la columna se han modificado correctamente
data_noid.head(2)
# Out:
#   age attrition business_travel  daily_rate department  distance_from_home  \
# 0  51        No             NaN           0        NaN                   6
# 1  52        No             NaN           0        NaN                   1
#
#    education education_field  employee_count employee_number  ...  \
# 0          3             NaN               1           162,0  ...
# 1          4   Life Sciences               1           259,0  ...
#
#    work_life_balance  years_at_company years_in_current_role  \
# 0                3,0                20                   NaN
# 1                3,0                33                   NaN
#
#    years_since_last_promotion  years_with_curr_manager date_birth  \
# 0                          15                       15       1972
# 1                          11                        9       1971
#
#         salary role_department number_children  remote_work
# 0  1000000000$             NaN             NaN          Yes
# 1  1000000000$             NaN             NaN            1
#
# [2 rows x 40 columns]

# %% [markdown]
# - `age` es `object` y debería ser `int`
# - `hourly_rate` aparece como `object` y debería ser `int`
# - `monthly_income`: convertir a `int`

# %%
columnas3 = ['age', 'hourly_rate', 'monthly_income']

# Itera sobre cada columna en la lista de columnas a convertir
for columna in columnas3:
    # Asegúrate de que los valores de la columna son de tipo string
    data_noid[columna] = data_noid[columna].astype(str)
    # Elimina cualquier valor no numérico o vacío y reemplaza por 0
    data_noid[columna] = data_noid[columna].replace(['nan', '', ' '], '0')
    # Convierte la columna a tipo numérico (int)
    data_noid[columna] = pd.to_numeric(data_noid[columna], errors='coerce').fillna(0).astype(int)

# Muestra las primeras filas del DataFrame para verificar que los valores de las columnas se han modificado correctamente
data_noid.head(2)
# Out:
#    age attrition business_travel  daily_rate department  distance_from_home  \
# 0   51        No             NaN           0        NaN                   6
# 1   52        No             NaN           0        NaN                   1
#
#    education education_field  employee_count employee_number  ...  \
# 0          3             NaN               1           162,0  ...
# 1          4   Life Sciences               1           259,0  ...
#
#    work_life_balance  years_at_company  years_in_current_role  \
# 0                3,0                20                    NaN
# 1                3,0                33                    NaN
#
#    years_since_last_promotion  years_with_curr_manager date_birth  \
# 0                          15                       15       1972
# 1                          11                        9       1971
#
#         salary role_department  number_children  remote_work
# 0  1000000000$             NaN              NaN          Yes
# 1  1000000000$             NaN              NaN            1
#
# [2 rows x 40 columns]

# %% [markdown]
# - `employee_number` sale como `float` y debería ser `int`

# %%
# Eliminar caracteres no numéricos de 'employee_number'
data_noid['employee_number'] = data_noid['employee_number'].astype(str).str.replace('[^0-9.]', '', regex=True)

# Rellenar los valores NaN con 0
data_noid['employee_number'] = pd.to_numeric(data_noid['employee_number'], errors='coerce').fillna(0)

# Convertir la columna 'employee_number' de float a int
data_noid['employee_number'] = data_noid['employee_number'].astype(int)

# Mostrar los primeros registros para verificar
data_noid.head(2)
# Out:
#    age attrition business_travel  daily_rate department  distance_from_home  \
# 0   51        No             NaN           0        NaN                   6
# 1   52        No             NaN           0        NaN                   1
#
#    education education_field  employee_count  employee_number  ...  \
# 0          3             NaN               1             1620  ...
# 1          4   Life Sciences               1             2590  ...
#
#    work_life_balance  years_at_company  years_in_current_role  \
# 0                3,0                20                    NaN
# 1                3,0                33                    NaN
#
#    years_since_last_promotion  years_with_curr_manager date_birth  \
# 0                          15                       15       1972
# 1                          11                        9       1971
#
#         salary role_department  number_children  remote_work
# 0  1000000000$             NaN              NaN          Yes
# 1  1000000000$             NaN              NaN            1
#
# [2 rows x 40 columns]

# %% [markdown]
# - cambiar todos los `valores` a `minúsculas`

# %%
# Lista de columnas a convertir a minúsculas de al 0 a la 21
columns_to_lower = [
    'age', 'attrition', 'business_travel', 'daily_rate', 'department', 
    'distance_from_home', 'education', 'education_field', 'employee_count', 
    'employee_number', 'environment_satisfaction', 'gender', 'hourly_rate', 
    'job_involvement', 'job_level', 'job_role', 'job_satisfaction', 
    'marital_status', 'monthly_income', 'monthly_rate'
]

# Convertir a minúsculas las columnas especificadas
for column in columns_to_lower:
    if data_noid[column].dtype == 'object':  # Verifica si la columna es de tipo str
        data_noid[column] = data_noid[column].str.lower()
        
data_noid.head(5)
# Out:
#    age attrition business_travel  daily_rate                department  \
# 0   51        no             NaN           0                       NaN
# 1   52        no             NaN           0                       NaN
# 2   42        no   travel_rarely           0   research & development
# 3   47        no   travel_rarely           0                       NaN
# 4   46        no             NaN           0                       NaN
#
#    distance_from_home  education   education_field  employee_count  \
# 0                   6          3               NaN               1
# 1                   1          4     life sciences               1
# 2                   4          2  technical degree               1
# 3                   2          4           medical               1
# 4                   3          3  technical degree               1
#
#    employee_number  ...  work_life_balance  years_at_company  \
# 0             1620  ...                3,0                20
# 1             2590  ...                3,0                33
# 2             3190  ...                NaN                22
# 3                0  ...                NaN                20
# 4                0  ...                3,0                19
#
#    years_in_current_role  years_since_last_promotion  years_with_curr_manager  \
# 0                    NaN                          15                       15
# 1                    NaN                          11                        9
# 2                    NaN                          11                       15
# 3                    NaN                           5                        6
# 4                    NaN                           2                        8
#
#   date_birth       salary                       role_department  \
# 0       1972  1000000000$                                   NaN
# 1       1971  1000000000$                                   NaN
# 2       1981  1000000000$   ManaGER  -  Research & Development
# 3       1976  1000000000$                                   NaN
# 4       1977  1000000000$                                   NaN
#
#    number_children  remote_work
# 0              NaN          Yes
# 1              NaN            1
# 2              NaN            1
# 3              NaN        False
# 4              NaN            0
#
# [5 rows x 40 columns]

# %% [markdown]
# - quitar los `NaN` de las columnas que lo tengan

# %%
# Reemplazar NaN en las columnas especificadas por 'No aplica'
columns_to_replace = ['business_travel', 'department', 'education_field', 'marital_status']
replacement_value = 'no aplica'

data_noid[columns_to_replace] = data_noid[columns_to_replace].fillna(replacement_value)

# Mostrar los primeros registros para verificar
data_noid.head(2)
# Out:
#    age attrition business_travel  daily_rate department  distance_from_home  \
# 0   51        no       no aplica           0  no aplica                   6
# 1   52        no       no aplica           0  no aplica                   1
#
#    education education_field  employee_count  employee_number  ...  \
# 0          3       no aplica               1             1620  ...
# 1          4   life sciences               1             2590  ...
#
#    work_life_balance  years_at_company  years_in_current_role  \
# 0                3,0                20                    NaN
# 1                3,0                33                    NaN
#
#    years_since_last_promotion  years_with_curr_manager date_birth  \
# 0                          15                       15       1972
# 1                          11                        9       1971
#
#         salary role_department  number_children  remote_work
# 0  1000000000$             NaN              NaN          Yes
# 1  1000000000$             NaN              NaN            1
#
# [2 rows x 40 columns]

# %% [markdown]
# ## Limpiamos las columnas de la 21 a la 31 (ambas incluidas)

# %% [markdown]
# Columnas verificadas donde no había nada que modificar:
#
# - COLUMNA 21: "num_companies_worked" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.
#
# - COLUMNA 24: "percent_salary_hike" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.
#
# - COLUMNA 26: "relationship_satisfaction" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.
#
# - COLUMNA 28: "stock_option_level" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.
#
# - COLUMNA 30: "training_times_last_year" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.
#
# - COLUMNA 32: "years_at_company" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.
#
# - COLUMNA 34: "years_since_last_promotion" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.
#
# - COLUMNA35: "years_with_curr_manager" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.
#
# - COLUMNA36: "date_birth" tiene 1614 entradas no nulas, como int64, hemos hecho un sample para doble verificación.

# %%
# Comprobación de la columna 21
data_noid["num_companies_worked"].sample(5)
# Out:
# 1198    1
# 919     1
# 1005    1
# 443     4
# 234     1
# Name: num_companies_worked, dtype: int64

# %%
# Comprobación de la columna 22
data_noid["over_18"].sample(5)
# Out:
# 745     NaN
# 1010    NaN
# 827       Y
# 159       Y
# 810     NaN
# Name: over_18, dtype: object

# %%
# LIMPIEZA DE LA COLUMNA 22 "over_18"
nuevos_valores = {"Y": "Yes", "N": "No"}
data_noid["over_18"] = data_noid["over_18"].map(nuevos_valores)
data_noid['over_18'] = data_noid['over_18'].fillna('N/A') #Usamos el "fillna" para cambiar el Nan (formato numpy) a N/A

# %%
# Comprobación de la columna 23
data_noid["overtime"].sample(5)
# Out:
# 826      No
# 557      No
# 1091    NaN
# 709     NaN
# 1232     No
# Name: overtime, dtype: object

# %%
# LIMPIEZA DE LA COLUMNA 23 "overtime"
data_noid['overtime'] = data_noid['overtime'].fillna('N/A') #Usamos el "fillna" para cambiar el Nan (formato numpy) a N/A

# %%
# Comprobación de la columna 24
data_noid["percent_salary_hike"].sample(5)
# Out:
# 621    18
# 686    16
# 496    19
# 13     12
# 582    13
# Name: percent_salary_hike, dtype: int64

# %%
# Comprobación de la columna 25
data_noid["performance_rating"].sample(5)
# Out:
# 948    3,0
# 483    3,0
# 199    3,0
# 177    4,0
# 684    NaN
# Name: performance_rating, dtype: object

# %%
# LIMPIEZA DE LA COLUMNA 25 "performance_rating"

# Nos aseguramos de que todos los valores son cadenas usando .astype(str)
data_noid["performance_rating"] = data_noid["performance_rating"].astype(str)

# Reemplazamos las comas por puntos
data_noid["performance_rating"] = data_noid["performance_rating"].str.replace(',', '.')

# Convertimos la columna a tipo numérico (dtype: "object" pasa a ser dtype: "float64")
data_noid["performance_rating"] = pd.to_numeric(data_noid["performance_rating"], errors='coerce')

# Cambiamos los valores que aparecen como NaN para darles valor 0
data_noid["performance_rating"] = data_noid["performance_rating"].fillna(0) 

# Cambiamos los valores de tipo string a int usando ".astype(int)"
data_noid["performance_rating"] = data_noid["performance_rating"].astype(int)

# %%
# Comprobación de la columna 26
data_noid["relationship_satisfaction"].sample(5)
# Out:
# 771     3
# 1328    2
# 352     4
# 698     3
# 939     4
# Name: relationship_satisfaction, dtype: int64

# %%
# Comprobación de la columna 27
data_noid["standard_hours"].sample(5)
# Out:
# 131    80,0
# 455     NaN
# 448     NaN
# 23     80,0
# 389    80,0
# Name: standard_hours, dtype: object

# %%
# LIMPIEZA DE LA COLUMNA 27 "standard_hours"

# Nos aseguramos de que todos los valores son cadenas usando .astype(str)
data_noid["standard_hours"] = data_noid["standard_hours"].astype(str)

# Reemplazamos las comas por puntos
data_noid["standard_hours"] = data_noid["standard_hours"].str.replace(',', '.')

# Convertimos la columna a tipo numérico (dtype: "object" pasa a ser dtype: "float64")
data_noid["standard_hours"] = pd.to_numeric(data_noid["standard_hours"], errors='coerce')

# Cambiamos los valores que aparecen como NaN para darles valor 0
data_noid["standard_hours"] = data_noid["standard_hours"].fillna(0) 

# Cambiamos los valores de tipo string a int usando ".astype(int)"
data_noid["standard_hours"] = data_noid["standard_hours"].astype(int)

# %%
# Comprobación de la columna 28
data_noid["stock_option_level"].sample(5)
# Out:
# 1074    1
# 690     1
# 1350    0
# 958     1
# 920     0
# Name: stock_option_level, dtype: int64

# %%
# Comprobación de la columna 29
data_noid["total_working_years"].sample(5)
# Out:
# 1243     NaN
# 1221    10,0
# 1269    17,0
# 704      6,0
# 798      5,0
# Name: total_working_years, dtype: object

# %%
# LIMPIEZA DE LA COLUMNA 29 "total_working_years"

# Nos aseguramos de que todos los valores son cadenas usando .astype(str)
data_noid["total_working_years"] = data_noid["total_working_years"].astype(str)

# Reemplazamos las comas por puntos
data_noid["total_working_years"] = data_noid["total_working_years"].str.replace(',', '.')

# Convertimos la columna a tipo numérico (dtype: "object" pasa a ser dtype: "float64")
data_noid["total_working_years"] = pd.to_numeric(data_noid["total_working_years"], errors='coerce')

# Cambiamos los valores que aparecen como NaN para dales valor 0
data_noid["total_working_years"] = data_noid["total_working_years"].fillna(0) 

# Cambiamos los valores de tipo string a int usando ".astype(int)"
data_noid["total_working_years"] = data_noid["total_working_years"].astype(int)

# %%
# Comprobación de la columna 30
data_noid["training_times_last_year"].sample(5)
# Out:
# 1111    2
# 458     2
# 1481    5
# 1341    2
# 1410    4
# Name: training_times_last_year, dtype: int64

# %%
# Comprobación de la columna 31
data_noid["work_life_balance"].sample(5)
# Out:
# 583     3,0
# 30      4,0
# 474     3,0
# 1280    2,0
# 1491    3,0
# Name: work_life_balance, dtype: object

# %%
# LIMPIEZA DE LA COLUMNA 31 "work_life_balance"

# Nos aseguramos de que todos los valores son cadenas usando .astype(str)
data_noid["work_life_balance"] = data_noid["work_life_balance"].astype(str)

# Reemplazamos las comas por puntos
data_noid["work_life_balance"] = data_noid["work_life_balance"].str.replace(',', '.')

# Convertimos la columna a tipo numérico (dtype: "object" pasa a ser dtype: "float64")
data_noid["work_life_balance"] = pd.to_numeric(data_noid["work_life_balance"], errors='coerce')

# Cambiamos los valores que aparecen como NaN para darles valor 0
data_noid["work_life_balance"] = data_noid["work_life_balance"].fillna(0) 

# Cambiamos los valores de tipo string a int usando ".astype(int)"
data_noid["work_life_balance"] = data_noid["work_life_balance"].astype(int)

# %%
data_noid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1614 entries, 0 to 1613
# Data columns (total 40 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         1614 non-null   int64
#  1   attrition                   1614 non-null   object
#  2   business_travel             1614 non-null   object
#  3   daily_rate                  1614 non-null   int64
#  4   department                  1614 non-null   object
#  5   distance_from_home          1614 non-null   int64
#  6   education                   1614 non-null   int64
#  7   education_field             1614 non-null   object
#  8   employee_count              1614 non-null   int64
#  9   employee_number             1614 non-null   int64
#  10  environment_satisfaction    1614 non-null   int64
#  11  gender                      1614 non-null   int64
#  12  hourly_rate                 1614 non-null   int64
#  13  job_involvement             1614 non-null   int64
#  14  job_level                   1614 non-null   int64
#  15  job_role                    1614 non-null   object
#  16  job_satisfaction            1614 non-null   int64
#  17  marital_status              1614 non-null   object
#  18  monthly_income              1614 non-null   int64
#  19  monthly_rate                1614 non-null   int64
#  20  num_companies_worked        1614 non-null   int64
#  21  over_18                     1614 non-null   object
#  22  overtime                    1614 non-null   object
#  23  percent_salary_hike         1614 non-null   int64
#  24  performance_rating          1614 non-null   int64
#  25  relationship_satisfaction   1614 non-null   int64
#  26  standard_hours              1614 non-null   int64
#  27  stock_option_level          1614 non-null   int64
#  28  total_working_years         1614 non-null   int64
#  29  training_times_last_year    1614 non-null   int64
#  30  work_life_balance           1614 non-null   int64
#  31  years_at_company            1614 non-null   int64
#  32  years_in_current_role       34 non-null     object
#  33  years_since_last_promotion  1614 non-null   int64
#  34  years_with_curr_manager     1614 non-null   int64
#  35  date_birth                  1614 non-null   int64
#  36  salary                      1614 non-null   object
#  37  role_department             302 non-null    object
#  38  number_children             0 non-null      float64
#  39  remote_work                 1614 non-null   object
# dtypes: float64(1), int64(27), object(12)
# memory usage: 504.5+ KB

# %%
# Comprobación de la columna 32
data_noid["years_at_company"].sample(5)
# Out:
# 561    10
# 380    10
# 228     9
# 236    10
# 818     3
# Name: years_at_company, dtype: int64

# %%
# Comprobación de la columna 33
data_noid['years_in_current_role'] = data_noid['years_in_current_role'].fillna('N/A')

# %%
# Comprobación de la columna 34
data_noid["years_since_last_promotion"].sample(5)
# Out:
# 537     1
# 1477    0
# 100     5
# 616     0
# 348     1
# Name: years_since_last_promotion, dtype: int64

# %%
# Comprobación de la columna 35
data_noid["years_with_curr_manager"].sample(5)
# Out:
# 1223    2
# 1462    0
# 936     3
# 1529    0
# 1183    2
# Name: years_with_curr_manager, dtype: int64

# %%
# Comprobación de la columna 36
data_noid["date_birth"].sample(5)
# Out:
# 1145    1978
# 1286    1981
# 1247    2000
# 629     1971
# 1483    1990
# Name: date_birth, dtype: int64

# %%
# Comprobación de la columna 37 #Ver con equipo que quieren hacer
data_noid["salary"].sample(25)
data_noid["salary"] = data_noid["salary"].str.replace('1000000000$', 'Unknown')

# %%
# Comprobación de la columna 38

data_noid["role_department"] = data_noid["role_department"].fillna('N/A')

# %%
# Comprobación de la columna 39

data_noid["number_children"] = data_noid["number_children"].fillna('N/A')

# %%
# Comprobación de la columna 40
data_noid["remote_work"].sample(25)

#primero paso todo a lower para usar el lambda
data_noid['remote_work'] = data_noid['remote_work'].str.lower()

# Reemplazar valores que no sean "yes" o "no" con "no"
data_noid['remote_work'] = data_noid['remote_work'].apply(lambda x: 'yes' if x == 'yes' else 'no')

# %%
data_noid["remote_work"].sample(25)
# Out:
# 726     yes
# 972      no
# 935      no
# 381     yes
# 1470     no
# 361      no
# 1379     no
# 116      no
# 598      no
# 1571     no
# 701      no
# 829      no
# 245      no
# 516      no
# 506      no
# 379      no
# 1090     no
# 210      no
# 475     yes
# 905      no
# 418      no
# 1355     no
# 1509     no
# 236      no
# 913      no
# Name: remote_work, dtype: object
